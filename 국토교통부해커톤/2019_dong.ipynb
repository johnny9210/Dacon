# %%
import pandas as pd
import os
import glob
import openpyxl

# %%
input_file = r'C:\Users\vxpko\202105_lab\HakerTon\data\2019' 
output_file = r'C:\Users\vxpko\202105_lab\HakerTon\data\2019_dong.csv'

# %%
allFile_list = glob.glob(os.path.join(input_file, '*.csv'))

allData = [] 
for file in allFile_list:
    try:
        df = pd.read_csv(file,encoding='utf-8',index_col=False) 
        print(file)
        df=pd.DataFrame(df)        
        allData.append(df) 
    except:
        df = pd.read_csv(file,encoding='euc-kr',index_col=False) 
        print(file)
        df=pd.DataFrame(df)        
        allData.append(df) 
dataCombine = pd.concat(allData, axis=0)
dataCombine.to_csv(output_file,index=False)
# Out:
# C:\Users\vxpko\202105_lab\HakerTon\data\2019\201901.csv
# C:\Users\vxpko\202105_lab\HakerTon\data\2019\201902.csv
# C:\Users\vxpko\202105_lab\HakerTon\data\2019\201903.csv
# C:\Users\vxpko\202105_lab\HakerTon\data\2019\201904.csv
# C:\Users\vxpko\202105_lab\HakerTon\data\2019\201905.csv
# C:\Users\vxpko\202105_lab\HakerTon\data\2019\201906.csv
# C:\Users\vxpko\202105_lab\HakerTon\data\2019\201907.csv
# C:\Users\vxpko\202105_lab\HakerTon\data\2019\201908.csv
# C:\Users\vxpko\202105_lab\HakerTon\data\2019\201909.csv
# C:\Users\vxpko\202105_lab\HakerTon\data\2019\201911.csv
# C:\Users\vxpko\202105_lab\HakerTon\data\2019\201912.csv

# %%
data=pd.read_csv('./data/2019_dong.csv')

# %%
data=data.iloc[:,[0,1,2,3,6,7,8,9,10,20,21,22,23,24]]

# %%
data=data.astype('int')

# %%
code=pd.read_excel('./code.xlsx', engine='openpyxl')
code=code[code['시도명']=='서울특별시'].iloc[:,:6]
for i in range(769):
    code['행정동코드'][i]=int(str(code['행정동코드'][i])[:8])
    code['법정동코드'][i]=int(str(code['법정동코드'][i])[:8])
# Out:
# <ipython-input-7-55c3fb8ac358>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   code['행정동코드'][i]=int(str(code['행정동코드'][i])[:8])
# <ipython-input-7-55c3fb8ac358>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   code['법정동코드'][i]=int(str(code['법정동코드'][i])[:8])

# %%
total=pd.merge(data,code,on='행정동코드')

# %%
total
# Out:
#             기준일ID  시간대구분     행정동코드  총생활인구수  남자15세부터19세생활인구수  남자20세부터24세생활인구수  \
# 0        20190101      0  11110515   14943              358              462
# 1        20190101      0  11110515   14943              358              462
# 2        20190101      0  11110515   14943              358              462
# 3        20190101      0  11110515   14943              358              462
# 4        20190101      0  11110515   14943              358              462
# ...           ...    ...       ...     ...              ...              ...
# 5883739  20191231     19  11740700   28966              760              675
# 5883740  20191231     20  11740700   29495              788              703
# 5883741  20191231     21  11740700   30131              787              704
# 5883742  20191231     22  11740700   31575              810              756
# 5883743  20191231     23  11740700   32974              816              762
#
#          남자25세부터29세생활인구수  남자30세부터34세생활인구수  남자35세부터39세생활인구수  여자15세부터19세생활인구수  \
# 0                    527              480              531              372
# 1                    527              480              531              372
# 2                    527              480              531              372
# 3                    527              480              531              372
# 4                    527              480              531              372
# ...                  ...              ...              ...              ...
# 5883739              821              867             1098              649
# 5883740              889              918             1081              652
# 5883741              909              955             1164              707
# 5883742              932              989             1203              766
# 5883743              957              986             1254              780
#
#          여자20세부터24세생활인구수  여자25세부터29세생활인구수  여자30세부터34세생활인구수  여자35세부터39세생활인구수  \
# 0                    462              429              464              634
# 1                    462              429              464              634
# 2                    462              429              464              634
# 3                    462              429              464              634
# 4                    462              429              464              634
# ...                  ...              ...              ...              ...
# 5883739              695              792              869             1071
# 5883740              702              828              889             1088
# 5883741              750              846              919             1054
# 5883742              847              937              944             1162
# 5883743              871             1005              951             1220
#
#            시도명 시군구명   읍면동명     법정동코드  동리명
# 0        서울특별시  종로구  청운효자동  11110101  청운동
# 1        서울특별시  종로구  청운효자동  11110102  신교동
# 2        서울특별시  종로구  청운효자동  11110103  궁정동
# 3        서울특별시  종로구  청운효자동  11110104  효자동
# 4        서울특별시  종로구  청운효자동  11110105  창성동
# ...        ...  ...    ...       ...  ...
# 5883739  서울특별시  강동구  둔촌제2동  11740106  둔촌동
# 5883740  서울특별시  강동구  둔촌제2동  11740106  둔촌동
# 5883741  서울특별시  강동구  둔촌제2동  11740106  둔촌동
# 5883742  서울특별시  강동구  둔촌제2동  11740106  둔촌동
# 5883743  서울특별시  강동구  둔촌제2동  11740106  둔촌동
#
# [5883744 rows x 19 columns]

# %%
total['10대_남']=total.iloc[:,4]
total['20대_남']=total.iloc[:,5]+total.iloc[:,6]
total['30대_남']=total.iloc[:,7]+total.iloc[:,8]
total['10대_합']=total.iloc[:,4]+total.iloc[:,9]
total['20대_합']=total.iloc[:,5]+total.iloc[:,6]+total.iloc[:,10]+total.iloc[:,11]
total['30대_합']=total.iloc[:,7]+total.iloc[:,8]+total.iloc[:,12]+total.iloc[:,13]

# %%
total.drop(total.iloc[:,4:14],axis=1,inplace=True)

# %%
total.to_csv('2019_dong.csv',index=False)
